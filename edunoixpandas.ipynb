# %%
# %%latex
#
# 1/2+5/5
# Out:
# 1/2+5/5

# %%
# %%timeit?

# %% [markdown]
# ### pandas

# %%
import pandas as pd
from sklearn import datasets

iris=pd.read_csv('/home/cryzal/$/home/cryzal/ml/dataset/iris.csv')
#iris.info
iris.describe()
#iris.describe()
#iris['Sepal.Length'].median()
#iris.groupby('Species').describe()
#iris.median()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#iris[1:11]
# iris.iloc[1:21,1:5]
# iris.iloc[0:51,0:5]
# iris[['Petal.Length','Sepal.Length']]
# iris['Sepal.Length']>6
#iris.info
#iris.loc[~iris['Petal.Length'].isin([4.2,5.0])]
#iris.iterrows()

#instead of doing this complex iteration we do easily go below

# for row, value in iris.iterrows():
#     if sum(value[:5]) >5:
#         iris.iloc[row,4] = "New"
# iris.replace("New","Better")      
# iris=pd.read_csv('/home/cryzal/$/home/cryzal/ml/dataset/iris.csv')

# x=iris[["Sepal.Length","Petal.Width"]]
# y=iris["Species"]
# x
iris.dtypes  
iris["Species"] = iris["Species"].astype('category')
iris.dtypes
iris["Species"]=iris["Species"].cat.codes
# iris["Species"] = iris["Species"].astype('category')
# iris.dtypes
# iris["Species"].cat.codes
# iris["Species"]=iris["Species"].cat.codes
# y=iris["Species"]
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
import pandas as pd
from sklearn import datasets
occu=pd.read_csv('/home/cryzal/$/home/cryzal/ml/dataset/datatest2.txt')
#occu.head
#occu.info
#occu["Light"][:100].plot(kind='line')
occu.set_index("date")["Light"][:100].plot(kind='line')

# %%
import pandas as pd
from sklearn import datasets
occu=pd.read_csv('/home/cryzal/$/home/cryzal/ml/dataset/datatest2.txt')
# occutemp =occu["Temperature"]
occutemp =occu["Temperature"].pct_change(periods=5)
occutemp
# Out:
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
#           ...
# 9748    0.001203
# 9749    0.003608
# 9750    0.004810
# 9751    0.004810
# 9752    0.008888
# Name: Temperature, Length: 9752, dtype: float64

# %%
from sklearn import datasets
iris =datasets.load_iris()
data = iris['data']
column = iris['feature_names']
df = pd.DataFrame(data,columns=column)
df['species'] = iris['target']
# df.dtypes
# df.info()
# df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
import pandas as pd
iris=pd.read_csv("/home/cryzal/$/home/cryzal/ml/dataset/iris.csv")
iris.groupby("Species").median()
# Out:
#             Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0
